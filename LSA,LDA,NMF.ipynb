# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents= ["""Dance is a powerful and expressive form of art that has been an integral part of human culture for centuries, transcending boundaries of language, geography, and time. It is a unique way of communicating emotions, stories, and traditions through movement, rhythm, and music. From classical styles like Bharatanatyam and Kathak to modern forms such as hip-hop and contemporary, dance continues to evolve while preserving its cultural roots. It plays an important role in celebrations, rituals, and social gatherings, often reflecting the identity and heritage of a community. Beyond its artistic value, dance also offers numerous physical and mental benefits—it improves flexibility, strength, coordination, and overall fitness, while also reducing stress and boosting confidence. For many, dance is not just a performance but a form of self-expression and freedom, allowing individuals to connect with their inner emotions and share them with the world. Whether performed on grand stages or in casual settings, dance brings people together, inspires creativity, and celebrates the beauty of movement in its purest form."""]

# %% [markdown]
# # LSA

# %%
vectorizer=TfidfVectorizer(stop_words='english')
x=vectorizer.fit_transform(documents)

# %%
lsa=TruncatedSVD(n_components=3,random_state=42)
lsa_matrix=lsa.fit_transform(x)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/decomposition/_truncated_svd.py:273: RuntimeWarning: invalid value encountered in divide
#   self.explained_variance_ratio_ = exp_var / full_var

# %%
terms=vectorizer.get_feature_names_out()
for i, comp in enumerate(lsa.components_):
    print(f"\nTopic{i+1}:")
    terms_weights= zip(terms,comp)
    sorted_terms=sorted(terms_weights,key=lambda x:x[1],reverse=True)
    for term,weight in sorted_terms[:10]:
        print(term)
# Out:
# Topic1:
# dance
# form
# emotions
# movement
# art
# artistic
# beauty
# benefits
# bharatanatyam
# boosting

# %% [markdown]
# # NMF

# %%
from sklearn.decomposition import NMF

# %%
vectorizer=TfidfVectorizer(stop_words='english')
y=vectorizer.fit_transform(documents)

# %%
#Apply NMF
nmf=NMF(n_components=2,random_state=42)
fiting=nmf.fit_transform(y)
hedding=nmf.components_

# %%
#Display Topics
feature_names=vectorizer.get_feature_names_out()
for topic_idx,topic in enumerate(hedding):
  print(f"\nTopic {topic_idx+1}:")
  top_words=[feature_names[i] for i in topic.argsort()[-6:]]
  print(top_words)
# Out:
# Topic 1:
# ['way', 'casual', 'emotions', 'movement', 'form', 'dance']
#
# Topic 2:
# ['freedom', 'celebrations', 'inspires', 'grand', 'rhythm', 'dance']

# %% [markdown]
# # LDA

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
cv = CountVectorizer(max_df=1.0, min_df=1, stop_words='english')
z=cv.fit_transform(documents)

# %%
LDA = LatentDirichletAllocation(n_components=4,random_state=42)
LDA.fit(z)
# Out:
# LatentDirichletAllocation(n_components=4, random_state=42)

# %%
for z,topic in enumerate(LDA.components_):
  print(f'the top4 words for topic {z}')
  print([cv.get_feature_names_out()[a] for a in topic.argsort()[-20:]])
  print('\n')
# Out:
# the top4 words for topic 0
# ['rhythm', 'rituals', 'role', 'roots', 'self', 'settings', 'share', 'social', 'stages', 'stories', 'strength', 'stress', 'styles', 'time', 'traditions', 'transcending', 'unique', 'value', 'way', 'world']
#
#
# the top4 words for topic 1
# ['rhythm', 'rituals', 'role', 'roots', 'self', 'settings', 'share', 'social', 'stages', 'stories', 'strength', 'world', 'unique', 'value', 'way', 'transcending', 'emotions', 'movement', 'form', 'dance']
#
#
# the top4 words for topic 2
# ['rhythm', 'rituals', 'role', 'roots', 'self', 'settings', 'share', 'social', 'stages', 'stories', 'strength', 'stress', 'styles', 'time', 'traditions', 'transcending', 'unique', 'value', 'way', 'world']
#
#
# the top4 words for topic 3
# ['rhythm', 'rituals', 'role', 'roots', 'self', 'settings', 'share', 'social', 'stages', 'stories', 'strength', 'stress', 'styles', 'time', 'traditions', 'transcending', 'unique', 'value', 'way', 'world']
